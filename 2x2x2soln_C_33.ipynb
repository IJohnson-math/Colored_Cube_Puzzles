# %%
import csv

def csv_to_kvs(fileName):
    make_dictionary = {}
    with open(fileName,'r') as csvFile:
        csvreader = csv.reader(csvFile)
        for row in csvreader:
            #position 1 and following are integers
            make_dictionary[row[0]] = [int(val) for val in row[1:]]
        print(make_dictionary)
    return make_dictionary


C33=csv_to_kvs('C_33all.csv')  
print(C33)

print(len(C33.keys()))
# Out:
# {'111.123': [111, 111, 112, 112, 113, 113, 123, 132], '111.223': [111, 112, 112, 113, 221, 223, 123, 132], '111.332': [111, 113, 113, 112, 331, 332, 123, 132], '112.113': [112, 112, 112, 112, 113, 113, 113, 113], '112.233': [112, 113, 221, 223, 331, 332, 123, 132], '112.312': [112, 112, 112, 112, 123, 123, 132, 132], '112.313': [112, 112, 113, 113, 331, 331, 123, 132], '112.332': [112, 112, 332, 332, 123, 123, 132, 132], '113.212': [112, 112, 113, 113, 221, 221, 123, 132], '113.213': [113, 113, 113, 113, 123, 123, 132, 132], '113.223': [113, 113, 223, 223, 123, 123, 132, 132], '123.213': [123, 123, 123, 123, 132, 132, 132, 132], '221.223': [221, 221, 221, 221, 223, 223, 223, 223], '221.321': [221, 221, 221, 221, 123, 123, 132, 132], '221.323': [221, 221, 223, 223, 332, 332, 123, 132], '221.331': [221, 221, 331, 331, 123, 123, 132, 132], '222.113': [222, 221, 221, 223, 112, 113, 123, 132], '222.123': [222, 222, 221, 221, 223, 223, 123, 132], '222.331': [222, 223, 223, 221, 331, 332, 1
# ...

# %%
# %run module2x2x2_ext_match.ipynb

from datetime import date

today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2021-12-17

# %%
SolutionFrequencyList(C33, C33["111.123"])
# Out:
# [111, 111, 112, 112, 113, 113, 123, 132] and [221, 221, 221, 221, 223, 223, 223, 223] no intersection
# [111, 111, 112, 112, 113, 113, 123, 132] and [331, 331, 331, 331, 332, 332, 332, 332] no intersection
# There are 2220075 collections to make the target [111, 111, 112, 112, 113, 113, 123, 132]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/_1/zlj0blk520n02nhdgmttstk587yf41/T/ipykernel_1300/3431870102.py in <module>
# ----> 1 SolutionFrequencyList(C33, C33["111.123"])
#
# /var/folders/_1/zlj0blk520n02nhdgmttstk587yf41/T/ipykernel_1300/3614903228.py in SolutionFrequencyList(dictionary_of_cubes, target_cube)
#      79             print(".")
#      80
# ---> 81         soln_num = CountingSolutions(CornerCountVector(k, target_cube))
#      82         if soln_num > 0:
#      83             solutions.append(soln_num)
#
# ...

# %%
SolutionFrequencyList(C33, C33["111.223"])
# Out:
# [111, 112, 112, 113, 221, 223, 123, 132] and [331, 331, 331, 331, 332, 332, 332, 332] no intersection
# There are 3108105 collections to make the target [111, 112, 112, 113, 221, 223, 123, 132]
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %% [markdown]
# 99 at 8:36am 8/6
# 107 at 10:16am 8/6  (2.7days)

# %%
KeysFor111223={"111.223", 
"112.233",
"222.113",
"111.332",
"113.212",
"223.121",
"111.123",
"222.331",
"333.112",
"333.221",
"112.313",
"221.323",
"113.223",
"222.123"}

# %%
SubDictFor111223={key_max: C33[key_max] for key_max in KeysFor111223}
SolutionFrequencyList(SubDictFor111223, C33["111.223"])
# Out:
# There are 3003 collections to make the target [111, 112, 112, 113, 221, 223, 123, 132]
# Checked 3003 collections of 8 cubes
# 165 of the collections yield no solutions
#  22528 :  2
#  29136 :  1
#  25352 :  1
#  16156 :  1
#  35008 :  2
#  19396 :  1
#  17792 :  2
#  20832 :  2
#  12496 :  4
#  21264 :  2
#  9112 :  2
#  10592 :  5
#  27232 :  1
#  16448 :  4
#  32880 :  2
#  14840 :  1
#  14488 :  1
#  31184 :  1
#  17968 :  4
#  19472 :  1
#  10716 :  1
#  18392 :  1
#  45344 :  2
#  40848 :  2
#  26408 :  2
#  52640 :  2
#  28568 :  2
#  33088 :  1
#  46016 :  1
#  29472 :  1
#  68928 :  1
#  37920 :  1
#  19104 :  4
#  53392 :  1
#  35528 :  1
#  35384 :  1
#  22876 :  1
#  45704 :  1
#  42240 :  2
#  25888 :  2
#  48928 :  2
#  22000 :  2
#  26048 :  1
#  23664 :  2
#  46752 :  2
#  26400 :  3
#  30528 :  2
#  29680 :  2
#  15952 :  4
#  18560 :  1
#  26096 :  2
#  29920 :  2
#  12720 :  1
#  26592 :  1
#  61856 :  1
#  35440 :  1
#  39344 :  1
#  21560 :  1
#  41488 :  1
# ...

# %%
DifferentKeysFor111223={"111.223", "111.123", "112.312", "112.113", 
                        "221.223", "113.212", "113.223", "222.113", 
                        "221.321", "223.123","112.313",
                        "123.213", "112.233", "111.332"}
#without

# %%
DiffSubDictFor111223={key_max: C33[key_max] for key_max in DifferentKeysFor111223} 
SolutionFrequencyList(DiffSubDictFor111223, C33["111.223"])
# Out:
# There are 3003 collections to make the target [111, 112, 112, 113, 221, 223, 123, 132]
# Checked 3003 collections of 8 cubes
# 167 of the collections yield no solutions
#  39040 :  2
#  51840 :  3
#  31232 :  7
#  19456 :  7
#  24192 :  2
#  25856 :  6
#  23552 :  17
#  78208 :  1
#  58368 :  24
#  41984 :  3
#  48000 :  1
#  60160 :  4
#  55808 :  5
#  70656 :  5
#  56320 :  11
#  60928 :  6
#  85504 :  5
#  80384 :  6
#  38912 :  28
#  34816 :  26
#  55296 :  16
#  51200 :  18
#  25600 :  14
#  26624 :  16
#  39936 :  11
#  36352 :  6
#  21504 :  9
#  47936 :  1
#  39296 :  1
#  22272 :  3
#  29376 :  1
#  27904 :  4
#  25088 :  6
#  50432 :  7
#  29952 :  6
#  38464 :  1
#  35584 :  2
#  23040 :  6
#  24320 :  3
#  28160 :  3
#  14080 :  2
#  9728 :  6
#  18560 :  2
#  16384 :  46
#  7680 :  2
#  73472 :  4
#  52480 :  1
#  60096 :  1
#  71552 :  1
#  65792 :  2
#  49664 :  8
#  46336 :  2
#  64512 :  17
#  31488 :  3
#  26112 :  6
#  44416 :  1
#  39680 :  7
#  20992 :  2
# ...

# %%
#conjectured fourth collection with second largest solution number 229376
SomeKeysFor111223={"111.223", "111.123", "112.312", "112.113", "123.213", "221.223", "221.321", "223.121", "113.223", "113.213", "113.212", "223.123"}
SomeDictFor111223={key_max: C33[key_max] for key_max in SomeKeysFor111223}

SolutionFrequencyList(SomeDictFor111223, C33["111.223"])
# Out:
# There are 495 collections to make the target [111, 112, 112, 113, 221, 223, 123, 132]
# ([223, 223, 223, 223, 123, 123, 132, 132], [123, 123, 123, 123, 132, 132, 132, 132], [111, 111, 112, 112, 113, 113, 123, 132], [111, 112, 112, 113, 221, 223, 123, 132], [112, 112, 112, 112, 113, 113, 113, 113], [112, 112, 112, 112, 123, 123, 132, 132], [112, 112, 113, 113, 221, 221, 123, 132], [221, 221, 221, 221, 223, 223, 223, 223])
# There are 1 collections to make the target [112, 112, 112, 112, 113, 113, 113, 113]
# Checked 1 collections of 8 cubes
# 0 of the collections yield no solutions
#  82944 :  1

# %%
SolutionFrequencyList(C33, C33["111.123"])
# Out:
# [111, 111, 112, 112, 113, 113, 123, 132] and [221, 221, 221, 221, 223, 223, 223, 223] no intersection
# [111, 111, 112, 112, 113, 113, 123, 132] and [331, 331, 331, 331, 332, 332, 332, 332] no intersection
# There are 2220075 collections to make the target [111, 111, 112, 112, 113, 113, 123, 132]
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
#SomeKeysFor111123={"111.123", "111.223", "111.332", "112.233", "333.112", "222.113", "112.313", "113.212"}
#SubsetKeysFor111123={"111.123", "112.113", "112.312", "113.213", "123.213", "111.223", "111.332", "113.212", "112.313", "112.332", "113.223"}
Subset1KeysFor111123={"111.123", "112.113", "112.312", "113.213", "123.213", "111.223", "111.332", "113.212"} #, "112.313"} 
Subset2KeysFor111123={"111.123", "112.113", "112.312", "113.213", "123.213", "111.223", "111.332", "112.313"} #, "113.212"} #
SomeDictFor111123={key_max: C33[key_max] for key_max in Subset2KeysFor111123}
SolutionFrequencyList(SomeDictFor111123, C33["111.123"])
# Out:
# There are 1 collections to make the target [111, 111, 112, 112, 113, 113, 123, 132]
# Checked 1 collections of 8 cubes
# 0 of the collections yield no solutions
#  344064 :  1

# %%
SolutionFrequencyList(C33, C33["112.313"])
# Out:
# [112, 112, 113, 113, 331, 331, 123, 132] and [221, 221, 221, 221, 223, 223, 223, 223] no intersection
# There are 3108105 collections to make the target [112, 112, 113, 113, 331, 331, 123, 132]
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# ...

# %%
SolutionFrequencyList(C33, C33["112.312"])
# Out:
# [112, 112, 112, 112, 123, 123, 132, 132] and [221, 221, 221, 221, 223, 223, 223, 223] no intersection
# [112, 112, 112, 112, 123, 123, 132, 132] and [331, 331, 331, 331, 332, 332, 332, 332] no intersection
# There are 2220075 collections to make the target [112, 112, 112, 112, 123, 123, 132, 132]
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .
# .

# %%
SolutionFrequencyList(C33, C33["123.213"])
# Out:
# [123, 123, 123, 123, 132, 132, 132, 132] and [112, 112, 112, 112, 113, 113, 113, 113] no intersection
# [123, 123, 123, 123, 132, 132, 132, 132] and [221, 221, 221, 221, 223, 223, 223, 223] no intersection
# [123, 123, 123, 123, 132, 132, 132, 132] and [331, 331, 331, 331, 332, 332, 332, 332] no intersection
# There are 1562275 collections to make the target [123, 123, 123, 123, 132, 132, 132, 132]

# %%
keylist123213=[123.213, 112.312, 221.321, 223.123, 113.213, 113.223, 112.332, 221.331]
keyliststrings123213=[str(x) for x in keylist]
Dict123213={key: C33[key] for key in keyliststrings}

SolutionFrequencyList(Dict123213, C33["123.213"])

# %%
# Out:
# There are 1 collections to make the target [123, 123, 123, 123, 132, 132, 132, 132]
# Checked 1 collections of 8 cubes
# 0 of the collections yield no solutions
#  20643840 :  1

# %%
minKeyList123213=[222.123, 221.323, 222.331, 333.112, 333.221, 331.232, 332.131, 333.123]
minkeyliststrings123213=[str(x) for x in minKeyList123213]
minDict123213={key: C33[key] for key in minkeyliststrings123213}

SolutionFrequencyList(minDict123213, C33["123.213"])
# Out:
# There are 1 collections to make the target [123, 123, 123, 123, 132, 132, 132, 132]
# Checked 1 collections of 8 cubes
# 0 of the collections yield no solutions
#  40320 :  1
